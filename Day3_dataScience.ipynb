# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# ### line plot

# %%
x=np.array([3,11,16,23,27,34,48,55,56,67])
y=np.array([13,23,34,49,47,61,69,78,84,89])

# %%
plt.title('my first plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.grid()
plt.xlim(0,80)
plt.ylim(0,100)
plt.xticks(range(0,81,10))
plt.yticks(range(0,101,10))
plt.plot(x, y)

# %%
z = np.array([87,77,75,71,54,33,21,23,19,10])

# %%
plt.title('my first plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.grid()
plt.xlim(0,80)
plt.ylim(0,100)
plt.xticks(range(0,81,10))
plt.yticks(range(0,101,10))
# marker
plt.plot(x,y,marker='o', color='green',ls=':',lw=3,mfc='black')

# %%
plt.title('my first plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.grid()
plt.plot(x,y, label='2022' , color='blue')
plt.plot(x, z,label='2023',color='green')
plt.legend()

# %%
plt.subplot(1,2,1)
plt.plot(x,y)
plt.subplot(1,2,2)
plt.plot(x,z)

# %%
plt.figure(figsize=(16,9))
plt.title('my first plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.grid()
plt.xlim(0,80)
plt.ylim(0,100)
plt.xticks(range(0,81,10))
plt.yticks(range(0,101,10)
plt.plot(x,y, label='2022' , color='blue')
plt.plot(x, z,label='2023',color='green')
plt.legend()
# Out:
#   File "<ipython-input-69-402367279abe>", line 10
#     plt.plot(x,y, label='2022' , color='blue')
#     ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(16,9))
plt.title('my first plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.grid()
plt.plot(x,y, label='2022' , color='blue')
plt.plot(x, z,label='2023',color='green')
plt.legend()

# %%
plt.title('my first plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.grid()
plt.scatter(x,y)

# %%
java=np.array([56,65,45,54,63,36,62,56,59,55,58,85])
python=np.array([52,42,69,35,96,75,54,51,74,47,65,62])
cols=[1,2,1,3,2,1,3,2,3,3,2,1]

# %%
plt.title('my first plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.grid()
plt.scatter(java,python,c=cols)

# %%
percentage=[89.34,45.35,76.46,65.90,11.34,71.90]
subject=['python','PHP','Data Structure','java','c','oop']

# %%
plt.title('result analysis')
plt.xlabel('subject')
plt.ylabel('% of passing')
plt.grid()
plt.bar(subject,percentage,color='pink')
# Out:
# <BarContainer object of 6 artists>

# %%
plt.title('result analysis')
plt.xlabel('subject')
plt.ylabel('% of passing')
plt.grid()
plt.barh(subject,percentage,color='pink')
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ## pie chart

# %%
enrollment=[167,67,89,106,48,99]
course=['python','PHP','Data Structure','java','c','oop']

# %%
plt.figure(figsize=(10,10))
plt.pie(enrollment,labels=course,autopct=('%2.2f%%'));

# %%
import pandas as pd

# %%
df=pd.read_csv('imcc.csv')

# %%
plt.figure(figsize=(16,9))
plt.barh(df['name'],df['sgpa'])
# Out:
# <BarContainer object of 51 artists>

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ## Histogram

# %%
marks=  np.array([56,67,72,93,75,45,25,58,66,63,64,52])

# %%
plt.xlabel('range of marks')
plt.ylabel('Count')
plt.grid()
plt.xticks(range(0,101,10))
plt.hist(marks,color='pink', bins=range(0,101,10));

# %%
plt.boxplot(marks);

# %%
plt.boxplot(df['sgpa']);

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Salary_Data.csv')

# %%
df.shape
# Out:
# (30, 2)

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
plt.scatter(df['YearsExperience'],df['Salary'])

# %%
a=np.arange(1,10,0.25)

# %%
a
# Out:
# array([1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 ,
#        3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25, 5.5 , 5.75, 6.  , 6.25,
#        6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  , 8.25, 8.5 , 8.75, 9.  ,
#        9.25, 9.5 , 9.75])

# %%
b=a*1056+32.04

# %%
b
# Out:
# array([ 1088.04,  1352.04,  1616.04,  1880.04,  2144.04,  2408.04,
#         2672.04,  2936.04,  3200.04,  3464.04,  3728.04,  3992.04,
#         4256.04,  4520.04,  4784.04,  5048.04,  5312.04,  5576.04,
#         5840.04,  6104.04,  6368.04,  6632.04,  6896.04,  7160.04,
#         7424.04,  7688.04,  7952.04,  8216.04,  8480.04,  8744.04,
#         9008.04,  9272.04,  9536.04,  9800.04, 10064.04, 10328.04])

# %%
plt.plot(a,b)

# %% [markdown]
# ### separate input and output variable

# %%
x=df['YearsExperience'].values
y=df['Salary']

# %%
x
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#         4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#         7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5])

# %%
y;

# %%
x=x.reshape(30,1)

# %%
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %% [markdown]
# #### import the class

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### create the object of linearRegretion

# %%
regressor=LinearRegression()

# %% [markdown]
# ## train the algorithm with data

# %%
regressor.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ### predict on unseen data

# %%
regressor.predict([[15]])
# Out:
# array([167541.63502049])

# %%
regressor.predict([[20]])
# Out:
# array([214791.44662777])
